# %%
import matplotlib.pyplot as plt
img = plt.imread("/home/basta/Projects/vrgineers/RAW/cockpit-dark_left.png")
plt.imshow(img[1000:, 1000:])
plt.imsave("/home/basta/Projects/vrgineers/RAW_TEST/cockpit-dark_left_cropped.png", img[1000:, 1000:])
