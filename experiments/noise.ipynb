# %%
import matplotlib.pyplot as plt
import numpy as np

img = plt.imread("../out/bilinear.png")
cut = img[2600:, 1500:2500];
plt.imshow(cut)

# %%
mean_pixel = np.mean(cut, axis=(0,1))
np.sum((cut - mean_pixel)**2, axis=(0,1))/(cut.shape[0]*cut.shape[1])
# Out:
# array([0.00071766, 0.00023877, 0.000345  , 0.        ])
